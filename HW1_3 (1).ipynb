# %%
# import package (s) and create aliases
import numpy as np # this is ok .
from numpy import array # numpy instead of np
from numpy.linalg import inv as inv # ok.

# create arrays and do math on them
a1 = [ 5 , 8 , 13 ] # ok . but this is a ”list” not a mathematical array
a1
a2 = array ( [ 5 , 8 , 13 ] )
a2
a = array ([[ 5 , 8 , 13 ]])
a
#b1 = a1 .T
#b2 = a2 .T
b = a .T
b
c1 = a1 * 2
c1
c2 = a2 * 2
c2
c = a * 2
c
x = array ([9, 8, 7])*array(11)
x
x = b^3
x
x = b**3
x
p1 = a*b
p1
p2 = a * b . T
p2
p3 = a.T * b
p3
p4 = a @ b
#p5 = a @ b.T
#P6 = a.T @ b
p7 = a.T @ b.T
p8 = a @ b
#p9 = a2 @ b.T
q1 = a / b.T
q1 = a.T / b
q1 = a / b
#q2 = a \ b
bT = b.T
# multi dimensional arrays (matrices)
A1 = [b, b+21, b**2]
A1
#A2 = array (b, b+21, b**2)
A = np . vstack ([a , a+21, a**2])
A
x = inv (A) @ b
z = A @ x - b
z
AtA = A.T @ A
AtA
#Stacking arrays horizontally and vertically
B = np. hstack ([ b , b **2 ])
B
C = np. vstack ([ c +21 , c **2 ])
C
D = array ([ [1 ,2] , [3 ,4] ])
D
S = np. vstack ([ np. hstack ([ A , B ]), np. hstack ([ C , D ]) ])
S
#Indexing arrays
# u = [0:10]
u = np.linspace (1, 10, 10)
u
#v = u[10]
v = u[0]
v
v = u[-1]
v
v = u[2:5]
v
v = u[2:5+1]
v
v = A [2,0]
v
v = A [2] [0]
v
v = A[1,:]
v
v = A[1:3,:]
v
v = A[1:3,1:3]
v
v = u[6:-2:2]
v
v = u[6:4:2]
v

#Think of two more vector mistakes and two more matrix mistakes.
#Call them y , z , E , and F. And fix those mistakes

#vector mistakes
v1 = array([[2, 3, 5]])
#y = array([[2, 3, 5]]) ^ 2 #does not raise to power 2
#z = array([[2^2, 3^4, 5^3]]) #does not raise individual elements to the power


#fixes
y = array([[2, 3, 5]]) ** 2
y
z = array([[2**2, 3**4, 5**3]])
z

#matrix mistakes
m1 = array([[2, 4, 8],[6, 10, 12]])
m2 = [[2,3],[4,5]]
#E = m1 + m2 # invalid due to different size matrices
#F = m1/m2 # invalid due to different size matrices

#fixes
m1 = array([[2, 4],[6, 10]])
m2 = [[2,3],[4,5]]
E = m1 + m2
E
F = m1/m2
F

#u = np.arange (0, 10)
#u
#v = u[9]
#v
#Stacking arrays horizontally and vertically
# Out:
# array([[1.        , 1.33333333],
#        [1.5       , 2.        ]])
